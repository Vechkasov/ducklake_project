# %%
import duckdb
import os

def env(name, default=None):
    v = os.environ.get(name)
    return v if v not in (None, "") else default

def install_extensions(conn: duckdb.DuckDBPyConnection) -> None:
    conn.execute("""
        INSTALL ducklake;
        INSTALL postgres_scanner;
        INSTALL httpfs;
    """)

def chech_extensions(conn: duckdb.DuckDBPyConnection) -> None:
    print("Extensions:")
    conn.sql("""
        select extension_name, loaded, installed, description, aliases
        from duckdb_extensions()
        where 1 = 1
            and extension_name in ('ducklake', 'httpfs', 'postgres_scanner')
    """).show()


def create_secrets(conn: duckdb.DuckDBPyConnection) -> None:
    conn.execute(f"""
    CREATE OR REPLACE SECRET minio_storage (
        TYPE S3,
        KEY_ID '{env("MINIO_ROOT_USER")}',
        SECRET '{env("MINIO_ROOT_PASSWORD")}',
        ENDPOINT '{env("MINIO_ENDPOINT")}',
        REGION 'eu-central-1',
        USE_SSL false,
        URL_STYLE 'path',
        SCOPE 's3://{env("MINIO_BUCKET")}/'
    );
    """)

    conn.execute(f"""
    CREATE OR REPLACE SECRET pg_meta (
        TYPE POSTGRES,
        HOST '{env("POSTGRES_HOST")}',
        PORT {env("POSTGRES_PORT")},
        DATABASE '{env("POSTGRES_DB")}',
        USER '{env("POSTGRES_USER")}',
        PASSWORD '{env("POSTGRES_PASSWORD")}'
    );
    """)

    conn.execute(f"""
    ATTACH 'ducklake:postgres:' AS lake (
        META_SECRET pg_meta,
        DATA_PATH 's3://{env("MINIO_BUCKET")}/'
    );
    """)
    
    conn.execute("USE lake;")

with duckdb.connect() as conn:
    install_extensions(conn)
    # chech_extensions(conn)
    create_secrets(conn)

    print("Available secrets:")
    conn.sql("select name, type, scope FROM duckdb_secrets()").show()
    
    print("Database tables:")
    conn.sql("show tables").show()
    
    print("Schemas in lake:")
    conn.sql("from duckdb_schemas()").show()
# Out:
# Available secrets:
# ┌───────────────┬──────────┬────────────────────┐
# │     name      │   type   │       scope        │
# │    varchar    │ varchar  │     varchar[]      │
# ├───────────────┼──────────┼────────────────────┤
# │ minio_storage │ s3       │ ['s3://ducklake/'] │
# │ pg_meta       │ postgres │ []                 │
# └───────────────┴──────────┴────────────────────┘
#
# Database tables:
# ┌─────────┐
# │  name   │
# │ varchar │
# ├─────────┤
# │ 0 rows  │
# └─────────┘
#
# Schemas in lake:
# ┌───────┬──────────────────────────┬──────────────┬────────────────────┬─────────┬───────────────────────┬──────────┬─────────┐
# │  oid  │      database_name       │ database_oid │    schema_name     │ comment │         tags          │ internal │   sql   │
# │ int64 │         varchar          │    int64     │      varchar       │ varchar │ map(varchar, varchar) │ boolean  │ varchar │
# ├───────┼──────────────────────────┼──────────────┼────────────────────┼─────────┼───────────────────────┼──────────┼─────────┤
# │  2059 │ __ducklake_metadata_lake │         2055 │ information_schema │ NULL    │ {}                    │ true     │ NULL    │
# │  2056 │ __ducklake_metadata_lake │         2055 │ pg_catalog         │ NULL    │ {}                    │ true     │ NULL    │
# │  2062 │ __ducklake_metadata_lake │         2055 │ pg_temp_3          │ NULL    │ {}                    │ true     │ NULL    │
# │  2064 │ __ducklake_metadata_lake │         2055 │ pg_temp_4          │ NULL    │ {}                    │ true     │ NULL    │
# │  2066 │ __ducklake_metadata_lake │         2055 │ pg_temp_5          │ NULL    │ {}                    │ true     │ NULL    │
# │  2060 │ __ducklake_metadata_lake │         2055 │ pg_temp_6          │ NULL    │ {}                    │ true     │ NULL    │
# │  2068 │ __ducklake_metadata_lake │         2055 │ pg_temp_7          │ NULL    │ {}                    │ true     │ NULL    │
# │  2057 │ __ducklake_metadata_lake │         2055 │ pg_toast           │ NULL    │ {}                    │ true     │ NULL    │
# │  2063 │ __ducklake_metadata_lake │         2055 │ pg_toast_temp_3    │ NULL    │ {}                    │ true     │ NULL    │
# │  2065 │ __ducklake_metadata_lake │         2055 │ pg_toast_temp_4    │ NULL    │ {}                    │ true     │ NULL    │
# │  2067 │ __ducklake_metadata_lake │         2055 │ pg_toast_temp_5    │ NULL    │ {}                    │ true     │ NULL    │
# │  2061 │ __ducklake_metadata_lake │         2055 │ pg_toast_temp_6    │ NULL    │ {}                    │ true     │ NULL    │
# │  2069 │ __ducklake_metadata_lake │         2055 │ pg_toast_temp_7    │ NULL    │ {}                    │ true     │ NULL    │
# │  2058 │ __ducklake_metadata_lake │         2055 │ public             │ NULL    │ {}                    │ false    │ NULL    │
# │  2354 │ lake                     │         2350 │ main               │ NULL    │ {}                    │ false    │ NULL    │
# │  2356 │ lake                     │         2350 │ raw                │ NULL    │ {}                    │ false    │ NULL    │
# │  2355 │ lake                     │         2350 │ stage              │ NULL    │ {}                    │ false    │ NULL    │
# │   590 │ memory                   │          592 │ main               │ NULL    │ {}                    │ true     │ NULL    │
# │  2070 │ system                   │            0 │ information_schema │ NULL    │ {}                    │ true     │ NULL    │
# │     0 │ system                   │            0 │ main               │ NULL    │ {}                    │ true     │ NULL    │
# │  2071 │ system                   │            0 │ pg_catalog         │ NULL    │ {}                    │ true     │ NULL    │
# │  1994 │ temp                     │         1993 │ main               │ NULL    │ {}                    │ true     │ NULL    │
# ├───────┴──────────────────────────┴──────────────┴────────────────────┴─────────┴───────────────────────┴──────────┴─────────┤
# │ 22 rows                                                                                                           8 columns │
# └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
with duckdb.connect() as conn:
    create_secrets(conn)
    
    conn.sql("SELECT * FROM __ducklake_metadata_lake.information_schema.schemata;").show()
# Out:
# ┌──────────────────┬────────────────────┬───────────────────┬───────────────────────────────┬──────────────────────────────┬────────────────────────────┬──────────┐
# │   catalog_name   │    schema_name     │   schema_owner    │ default_character_set_catalog │ default_character_set_schema │ default_character_set_name │ sql_path │
# │     varchar      │      varchar       │      varchar      │            varchar            │           varchar            │          varchar           │ varchar  │
# ├──────────────────┼────────────────────┼───────────────────┼───────────────────────────────┼──────────────────────────────┼────────────────────────────┼──────────┤
# │ ducklake_catalog │ public             │ pg_database_owner │ NULL                          │ NULL                         │ NULL                       │ NULL     │
# │ ducklake_catalog │ pg_toast_temp_7    │ ducklake          │ NULL                          │ NULL                         │ NULL                       │ NULL     │
# │ ducklake_catalog │ pg_temp_7          │ ducklake          │ NULL                          │ NULL                         │ NULL                       │ NULL     │
# │ ducklake_catalog │ pg_toast_temp_5    │ ducklake          │ NULL                          │ NULL                         │ NULL                       │ NULL     │
# │ ducklake_catalog │ pg_temp_5          │ ducklake          │ NULL                          │ NULL                         │ NULL                       │ NULL     │
# │ ducklake_catalog │ pg_toast_temp_4    │ ducklake          │ NULL                          │ NULL                         │ NULL                       │ NULL     │
# │ ducklake_catalog │ pg_temp_4          │ ducklake          │ NULL                          │ NULL                         │ NULL                       │ NULL     │
# │ ducklake_catalog │ pg_toast_temp_3    │ ducklake          │ NULL                          │ NULL                         │ NULL                       │ NULL     │
# │ ducklake_catalog │ pg_temp_3          │ ducklake          │ NULL                          │ NULL                         │ NULL                       │ NULL     │
# │ ducklake_catalog │ pg_toast_temp_6    │ ducklake          │ NULL                          │ NULL                         │ NULL                       │ NULL     │
# │ ducklake_catalog │ pg_temp_6          │ ducklake          │ NULL                          │ NULL                         │ NULL                       │ NULL     │
# │ ducklake_catalog │ information_schema │ ducklake          │ NULL                          │ NULL                         │ NULL                       │ NULL     │
# │ ducklake_catalog │ pg_catalog         │ ducklake          │ NULL                          │ NULL                         │ NULL                       │ NULL     │
# │ ducklake_catalog │ pg_toast           │ ducklake          │ NULL                          │ NULL                         │ NULL                       │ NULL     │
# ├──────────────────┴────────────────────┴───────────────────┴───────────────────────────────┴──────────────────────────────┴────────────────────────────┴──────────┤
# │ 14 rows                                                                                                                                                7 columns │
# └──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
with duckdb.connect() as conn:
    create_secrets(conn)
    # conn.sql("from duckdb_schemas()").show()
    # conn.execute("use raw")
    conn.sql("""
    SELECT 
        be.event_id,
        be.click_id,
        be.event_timestamp,
        be.event_type,
        be.browser_name,
        de.os_name,
        de.device_type,
        de.user_custom_id,
        ge.geo_country,
        ge.geo_region_name,
        le.page_url_path,
        le.referer_medium,
        le.utm_source,
        le.utm_campaign,
        le.utm_medium
    FROM raw.browser_events be
    LEFT JOIN raw.device_events de ON be.click_id = de.click_id
    LEFT JOIN raw.geo_events ge ON be.click_id = ge.click_id
    LEFT JOIN raw.location_events le ON be.event_id = le.event_id
    """).show()
# Out:
# ┌──────────────────────────────────────┬──────────────────────────────────────┬─────────────────────────┬────────────┬──────────────────┬─────────┬─────────────┬─────────────────────────────────┬─────────────┬──────────────────────────────────┬───────────────────────────────────┬────────────────┬────────────┬──────────────┬────────────┐
# │               event_id               │               click_id               │     event_timestamp     │ event_type │   browser_name   │ os_name │ device_type │         user_custom_id          │ geo_country │         geo_region_name          │           page_url_path           │ referer_medium │ utm_source │ utm_campaign │ utm_medium │
# │                 uuid                 │                 uuid                 │        timestamp        │  varchar   │     varchar      │ varchar │   varchar   │             varchar             │   varchar   │             varchar              │              varchar              │    varchar     │  varchar   │   varchar    │  varchar   │
# ├──────────────────────────────────────┼──────────────────────────────────────┼─────────────────────────┼────────────┼──────────────────┼─────────┼─────────────┼─────────────────────────────────┼─────────────┼──────────────────────────────────┼───────────────────────────────────┼────────────────┼────────────┼──────────────┼────────────┤
# │ 2a00d244-cba0-4bed-9949-6f6ddfe27955 │ 54826ddf-7c13-405d-81e1-1432840137b1 │ 2025-11-27 18:00:01.492 │ pageview   │ Safari           │ iOS     │ Mobile      │ boitoeleanora@fastwebnet.it     │ IT          │ Sassari                          │ /product_flaska                   │ internal       │ telegram   │ campaign_1   │ social     │
# │ 697c4150-7526-4883-bc4d-e8013bb7f26e │ 1d5db31e-ae32-429f-a95a-1f4b632f5cb2 │ 2025-11-27 18:00:01.46  │ pageview   │ Firefox          │ MacOS   │ Computer    │ lodovicodeledda@gmail.com       │ IT          │ Portogruaro                      │ /home                             │ internal       │ telegram   │ campaign_1   │ affiliate  │
# │ 09528fed-2978-4cb1-b9a6-d6889c4f89fb │ 9814905c-4a0d-4d0f-af46-83e5b9bbbf96 │ 2025-11-27 18:00:01.784 │ pageview   │ Chrome           │ Windows │ Computer    │ melissa85@poste.it              │ IT          │ Falconara Marittima              │ /home                             │ search         │ google     │ campaign_1   │ organic    │
# │ 0d78bd36-9cbd-4ff1-9b84-3802342e75b6 │ 7c7f0010-8d31-4062-b65e-eaeb0cb8e909 │ 2025-11-27 18:00:02.677 │ pageview   │ Opera            │ Linux   │ Computer    │ renatabranciforte@fastwebnet.it │ IT          │ Lanciano                         │ /home                             │ internal       │ telegram   │ campaign_1   │ affiliate  │
# │ 2fad3a36-9749-4b30-bf8e-3651798e317a │ ad39235e-a2fa-4190-a839-fcafd5f3a09f │ 2025-11-27 18:00:01.777 │ pageview   │ Opera            │ iOS     │ Mobile      │ cmoretti@libero.it              │ IT          │ Lanciano                         │ /product_flaska                   │ internal       │ yandex     │ campaign_2   │ cpc        │
# │ e494dfe3-2ca8-45d0-8006-9732fb66c91b │ 8dbae9c8-dadd-489d-b29a-d3a151fac454 │ 2025-11-27 18:00:00.444 │ pageview   │ Chrome           │ iOS     │ Mobile      │ emilio88@gmail.com              │ IT          │ Chiavari                         │ /product_microphone               │ search         │ google     │ campaign_1   │ organic    │
# │ 67c5a566-52d7-444a-8873-8c214b6e73f6 │ b09d5fc1-97b8-4a10-9262-62a7c44e929f │ 2025-11-27 18:00:01.156 │ pageview   │ Chrome           │ iOS     │ Mobile      │ neccitullio@virgilio.it         │ IT          │ San Giuliano Milanese            │ /product_tolstovka                │ internal       │ mailchimp  │ campaign_1   │ affiliate  │
# │ c907463a-4d24-4b92-95b2-f83d2cac1a7d │ 8c6faeac-9f19-474a-9835-51db86fa8dd8 │ 2025-11-27 18:00:00.866 │ pageview   │ Firefox          │ Android │ Mobile      │ simonettaluria@tele2.it         │ IT          │ Somma Vesuviana                  │ /product_termos                   │ search         │ google     │ campaign_2   │ social     │
# │ 2a8d82b4-a527-4183-af4a-648d24a8c5a6 │ ba6a7914-dc4a-46c3-aa92-b8cd3865d247 │ 2025-11-27 18:00:00.305 │ pageview   │ Opera            │ MacOS   │ Computer    │ rosalia26@poste.it              │ IT          │ San Giuliano Milanese            │ /product_sertifikat_zapreta_kinzy │ internal       │ telegram   │ campaign_1   │ affiliate  │
# │ 1f4fe24a-3e8c-402a-97a5-e38a5448acb9 │ 88fe6325-c8dc-4f24-8600-f487f99540ce │ 2025-11-27 18:00:02.637 │ pageview   │ Safari           │ Android │ Mobile      │ fmancini@live.com               │ IT          │ Agrigento                        │ /product_coffee                   │ internal       │ dzen       │ campaign_1   │ organic    │
# │                  ·                   │                  ·                   │            ·            │    ·       │   ·              │  ·      │   ·         │         ·                       │ ·           │    ·                             │        ·                          │    ·           │  ·         │     ·        │    ·       │
# │                  ·                   │                  ·                   │            ·            │    ·       │   ·              │  ·      │   ·         │         ·                       │ ·           │    ·                             │        ·                          │    ·           │  ·         │     ·        │    ·       │
# │                  ·                   │                  ·                   │            ·            │    ·       │   ·              │  ·      │   ·         │         ·                       │ ·           │    ·                             │        ·                          │    ·           │  ·         │     ·        │    ·       │
# │ 64820b97-638b-4d78-a55a-fc9d502ba175 │ 316d86de-2c6e-4e2e-90da-13de58d67fb1 │ 2025-11-27 18:02:14.635 │ pageview   │ YandexBrowser    │ iOS     │ Mobile      │ sgarbiferdinando@tele2.it       │ IT          │ Perugia                          │ /product_tolstovka                │ internal       │ dzen       │ campaign_2   │ organic    │
# │ 70d4a5fb-5efc-41fc-81bf-0e511b13b078 │ fecd53a7-030f-44ee-9802-b44392ff1bbb │ 2025-11-27 18:02:12.392 │ pageview   │ Firefox          │ Android │ Mobile      │ pacettitiziano@alice.it         │ IT          │ Ventimiglia                      │ /product_fish_stick               │ internal       │ dzen       │ campaign_2   │ organic    │
# │ 5fb30ce1-88d5-40a0-87de-fcbfa2d01c1c │ f2096033-a688-4b4a-a97e-6b6853ff55e2 │ 2025-11-27 18:02:16.597 │ pageview   │ Safari           │ MacOS   │ Computer    │ gversace@yahoo.com              │ IT          │ Cordenons                        │ /product_galstuk                  │ internal       │ mailchimp  │ campaign_1   │ affiliate  │
# │ 0a8b57ed-2495-4fd1-a8d0-ee9e956dcdca │ 2906e689-5473-451e-a474-99928f7088b6 │ 2025-11-27 18:02:26.983 │ pageview   │ Firefox          │ Android │ Mobile      │ irma70@hotmail.it               │ IT          │ Mesagne                          │ /confirmation                     │ internal       │ mailchimp  │ campaign_2   │ cpc        │
# │ 81a3e8f5-a95c-4949-955d-2a1a5b1cbdc5 │ 88895ae7-fe26-4ed8-8922-7d1e36cc5806 │ 2025-11-27 18:02:24.186 │ pageview   │ Opera            │ Linux   │ Computer    │ salvatorebonomo@fastwebnet.it   │ IT          │ Sassari                          │ /payment                          │ search         │ google     │ campaign_1   │ cpc        │
# │ 5877e09c-9d99-44b8-818a-2306d07232f2 │ 6a98fbdf-6240-4ba5-9d78-650932c30137 │ 2025-11-27 18:02:25.307 │ pageview   │ Chrome           │ Android │ Mobile      │ tgiannelli@live.com             │ IT          │ Ragusa                           │ /payment                          │ internal       │ mailchimp  │ campaign_1   │ cpc        │
# │ e9558b5a-1ed5-4256-bd7c-4e09286b6506 │ bb5110a5-4693-45fc-bace-9f388fc0b619 │ 2025-11-27 18:02:28.575 │ pageview   │ YandexBrowser    │ iOS     │ Mobile      │ cmaggioli@gmail.com             │ IT          │ Falconara Marittima              │ /product_tolstovka                │ internal       │ mailchimp  │ campaign_1   │ cpc        │
# │ b1a984e2-0237-4392-aff5-83ee6e3f11fa │ f6343a28-3e5b-4840-a781-6b7b57322624 │ 2025-11-27 18:02:29.41  │ pageview   │ Firefox          │ Windows │ Computer    │ boiardoruggiero@alice.it        │ IT          │ Villabate                        │ /cart                             │ search         │ google     │ campaign_1   │ organic    │
# │ d7a8ca08-f636-4d7e-b580-be819f8ee68c │ b2f2514c-2975-4f4f-9101-798f68f051e1 │ 2025-11-27 18:02:25.739 │ pageview   │ InternetExplorer │ Android │ Mobile      │ ubaldo99@poste.it               │ IT          │ Montecchio Maggiore-Alte Ceccato │ /payment                          │ internal       │ dzen       │ campaign_1   │ organic    │
# │ e715137e-b2e9-4870-ae3a-f7682f6ddedc │ 9b3a17f6-259b-4664-82b0-3c0922abe759 │ 2025-11-27 18:02:25.076 │ pageview   │ YandexBrowser    │ MacOS   │ Computer    │ michela17@libero.it             │ IT          │ Ragusa                           │ /home                             │ internal       │ mailchimp  │ campaign_1   │ cpc        │
# ├──────────────────────────────────────┴──────────────────────────────────────┴─────────────────────────┴────────────┴──────────────────┴─────────┴─────────────┴─────────────────────────────────┴─────────────┴──────────────────────────────────┴───────────────────────────────────┴────────────────┴────────────┴──────────────┴────────────┤
# │ ? rows (>9999 rows, 20 shown)                                                                                                                                                                                                                                                                                                       15 columns │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
import time

def chech_extensions(conn: duckdb.DuckDBPyConnection) -> None:
    print("Extensions:")
    conn.sql("""
        select extension_name, loaded, installed, description, aliases
        from duckdb_extensions()
        where 1 = 1
            and extension_name in ('ducklake', 'httpfs', 'postgres_scanner')
    """).show()

with duckdb.connect() as conn:
    create_secrets(conn)
    # chech_extensions(conn)
    start_time = time.time()
    
    conn.sql("""
        select 'browser_events' as source, count(*) as cnt 
        from read_json('s3://ducklake/data/browser_events/*.jsonl')
            union all
        select 'device_events' as source, count(*) as cnt 
        from read_json('s3://ducklake/data/device_events/*.jsonl')
            union all
        select 'geo_events' as source, count(*) as cnt 
        from read_json('s3://ducklake/data/geo_events/*.jsonl')
            union all
        select 'location_events' as source, count(*) as cnt 
        from read_json('s3://ducklake/data/location_events/*.jsonl')
    """).show()

    end_time = time.time()

    elapsed_time = end_time - start_time
    print(f"The task took {elapsed_time:.2f} seconds to complete.")
# Out:
# ┌─────────────────┬─────────┐
# │     source      │   cnt   │
# │     varchar     │  int64  │
# ├─────────────────┼─────────┤
# │ browser_events  │ 3478779 │
# │ device_events   │ 3478779 │
# │ geo_events      │ 3478779 │
# │ location_events │ 3478779 │
# └─────────────────┴─────────┘
#
# The task took 773.87 seconds to complete.
